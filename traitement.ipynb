# %%
import pandas as pd

df = pd.read_csv('tableau_1.csv', sep = ';')

df.head(100)
# Out:
# C:\Users\MANEL\AppData\Local\Temp\ipykernel_5788\4067050840.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('tableau_1.csv', sep = ';')
#           Niveau         ZONE  ANNEE  \
# 0   Départements     01 - Ain   2018
# 1   Départements     01 - Ain   2018
# 2   Départements     01 - Ain   2018
# 3   Départements     01 - Ain   2018
# 4   Départements     01 - Ain   2018
# ..           ...          ...    ...
# 95  Départements  03 - Allier   2018
# 96  Départements  03 - Allier   2018
# 97  Départements  03 - Allier   2018
# 98  Départements  03 - Allier   2018
# 99  Départements  03 - Allier   2018
#
#                                      PATHOLOGIE      SEXE     Tranche d'age  \
# 0   01000-Maladies infectieuses et parasitaires     Homme  00-Moins d'un an
# 1   01000-Maladies infectieuses et parasitaires     Femme  00-Moins d'un an
# ...
